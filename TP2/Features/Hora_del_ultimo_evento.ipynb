# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/events_up_to_01062018.csv', low_memory=False)
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
df["hour"] = df['timestamp'].dt.hour

# %%
df = df[['person',"hour"]]
ult_hour = df.sort_values("person")
#hours = df.groupby("person")["hour"].value_counts().to_frame()
ult_hour = ult_hour.drop_duplicates("person",keep = "last")
ult_hour = ult_hour.set_index("person")

# %%
ult_hour.to_csv("data/ult_hora.csv",sep=",")

# %%
ult_hour
# Out:
#           hour
# person
# 0008ed71    13
# 00091926     1
# 00091a7a    14
# 000ba417    11
# 000c79fe     0
# 000e4d9e    18
# 000e619d    15
# 001001be    18
# 0010e89a    18
# 0016c4b5    18
# 001802e4    17
# 001804a2    12
# 0019e639    16
# 001a2273    13
# 001b0bf9    14
# 001ca5ee    14
# 001dfc31    23
# 001e9aea    21
# 0020152e    11
# 00202cdb    12
# 0022965d     1
# 0027574e    20
# 00295d74    22
# 002aea56    17
# 002b0188    11
# 002e74b2    13
# 002ed810    11
# 002fb981    20
# 00317e49     4
# 0031c75f     2
# ...        ...
# ffcaae19     2
# ffcaeaae    15
# ffccd5a1    21
# ffcf952b    13
# ffd41214     1
# ffd62616    11
# ffd9756a    10
# ffda14ca    18
# ffdafc72    15
# ffddd0ec    15
# ffde3628    10
# ffe066cc    13
# ffe53446    13
# ffe7e848    12
# ffeb80c5    20
# ffebdbc9    18
# ffecdf29    18
# ffecea3d    21
# ffed0342    16
# ffed3d0e     1
# ffee0f18     3
# ffef83e6    15
# fff1659c    19
# fff1b11a    14
# fff1caee    17
# fff2bdde    22
# ...
