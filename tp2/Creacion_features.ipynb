# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/events_up_to_01062018.csv', low_memory=False)
df['timestamp'] = pd.to_datetime(df['timestamp'])
df.head()
# Out:
#             timestamp           event    person  url      sku  \
# 0 2018-05-18 00:11:59  viewed product  4886f805  NaN   9288.0
# 1 2018-05-18 00:11:27  viewed product  ad93850f  NaN    304.0
# 2 2018-05-18 00:11:16  viewed product  0297fc1e  NaN   6888.0
# 3 2018-05-18 00:11:14  viewed product  2d681dd8  NaN  11890.0
# 4 2018-05-18 00:11:09  viewed product  cccea85e  NaN   7517.0
#
#                      model  condition storage           color skus  \
# 0  Samsung Galaxy J7 Prime  Excelente    32GB         Dourado  NaN
# 1                iPhone 5s  Muito Bom    32GB  Cinza espacial  NaN
# 2                iPhone 6S  Muito Bom    64GB        Prateado  NaN
# 3                 iPhone 7        Bom   128GB        Vermelho  NaN
# 4              LG G4 H818P  Excelente    32GB          Branco  NaN
#
#         ...       search_engine channel new_vs_returning city region country  \
# 0       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 1       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 2       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 3       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# 4       ...                 NaN     NaN              NaN  NaN    NaN     NaN
#
#   device_type screen_resolution operating_system_version browser_version
# 0         NaN               NaN                      NaN             NaN
# 1         NaN               NaN                      NaN             NaN
# 2         NaN               NaN                      NaN             NaN
# 3         NaN               NaN                      NaN             NaN
# 4         NaN               NaN                      NaN             NaN
#
# [5 rows x 23 columns]

# %%
user_features = df[['person']].drop_duplicates().copy()
user_features.set_index('person', inplace=True)
user_features.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [4886f805, ad93850f, 0297fc1e, 2d681dd8, cccea85e]

# %%
def crear_feature(nombre, evento):
    features = df.loc[df['event'] == evento]
    features = features.groupby('person')['event'].value_counts().unstack()
    features.rename(columns={evento:'cant_'+nombre}, inplace=True)
    return features

# %%
conversion = crear_feature('conversions', 'conversion')
user_features = user_features.join(conversion).fillna(0)

# %%
conversion = crear_feature('checkouts', 'checkout')
user_features = user_features.join(conversion).fillna(0)

# %%
viewed_product = crear_feature('viewed_product', 'viewed product')
user_features = user_features.join(viewed_product).fillna(0)

# %%
searched_product = crear_feature('searched_product', 'searched products')
user_features = user_features.join(searched_product).fillna(0)

# %%
campaign = crear_feature('ad_campaign_hit', 'ad campaign hit')
user_features = user_features.join(campaign).fillna(0)
user_features["ad_campaign_hit"] = user_features["cant_ad_campaign_hit"].apply(lambda x: True if x>0 else False)
#user_features = user_features.drop("cant_ad_campaign_hit",1)

# %%
lead = crear_feature('lead', 'lead')
user_features = user_features.join(lead).fillna(0)
#user_features["lead"] = user_features["cant_lead"].apply(lambda x: True if x>0 else False)
#user_features = user_features.drop("cant_lead",1)

# %%
brand_listing = crear_feature('brand_listing', 'brand listing')
user_features = user_features.join(brand_listing).fillna(0)
user_features["brand listing"] = user_features["cant_brand_listing"].apply(lambda x: True if x>0 else False)
#user_features = user_features.drop("cant_brand_listing",1)

# %%
user_features.describe().T
# Out:
#                          count       mean        std  min  25%   50%   75%  \
# cant_conversions       38829.0   0.182621   0.987561  0.0  0.0   0.0   0.0
# cant_checkouts         38829.0   1.682119   2.717728  0.0  1.0   1.0   2.0
# cant_viewed_product    38829.0  32.144119  79.762927  0.0  3.0  10.0  29.0
# cant_searched_product  38829.0   3.363878  12.897345  0.0  0.0   0.0   2.0
# cant_ad_campaign_hit   38829.0   4.928996  10.821833  0.0  1.0   2.0   5.0
# cant_lead              38829.0   0.025316   0.349768  0.0  0.0   0.0   0.0
# cant_brand_listing     38829.0   5.570888  23.437437  0.0  0.0   0.0   4.0
#
#                           max
# cant_conversions        129.0
# cant_checkouts          197.0
# cant_viewed_product    2355.0
# cant_searched_product   739.0
# cant_ad_campaign_hit    523.0
# cant_lead                38.0
# cant_brand_listing     1891.0

# %%
sesiones = df.copy()

# %%
sesiones.sort_values(by='timestamp', inplace=True)
sesiones['diff'] = sesiones.groupby('person')['timestamp'].diff() / np.timedelta64(1, 'h')
sesiones['diff'].fillna(0, inplace=True)

# %%
sesiones[['timestamp', 'person', 'diff']].head(10)
# Out:
#                   timestamp    person      diff
# 2307205 2018-01-01 08:09:31  0f4e2a4b  0.000000
# 1753202 2018-01-01 08:09:31  0f4e2a4b  0.000000
# 1753201 2018-01-01 08:09:31  0f4e2a4b  0.000000
# 1753200 2018-01-01 08:09:44  0f4e2a4b  0.003611
# 1753207 2018-01-01 08:45:29  0f4e2a4b  0.595833
# 2307206 2018-01-01 08:45:29  0f4e2a4b  0.000000
# 1753210 2018-01-01 08:45:29  0f4e2a4b  0.000000
# 1753203 2018-01-01 08:45:43  0f4e2a4b  0.003889
# 1753204 2018-01-01 08:48:57  0f4e2a4b  0.053889
# 1753213 2018-01-01 08:49:05  0f4e2a4b  0.002222

# %%
sesiones['new_session'] = sesiones.groupby('person')['diff'].apply(lambda x: x > 1.0)
sesiones['session_id'] = sesiones.groupby('person')['new_session'].cumsum()

# %%
sesiones[['timestamp', 'person', 'event', 'diff', 'session_id']].head()
# Out:
#                   timestamp    person              event      diff  session_id
# 2307205 2018-01-01 08:09:31  0f4e2a4b       visited site  0.000000         0.0
# 1753202 2018-01-01 08:09:31  0f4e2a4b  search engine hit  0.000000         0.0
# 1753201 2018-01-01 08:09:31  0f4e2a4b    ad campaign hit  0.000000         0.0
# 1753200 2018-01-01 08:09:44  0f4e2a4b     viewed product  0.003611         0.0
# 1753207 2018-01-01 08:45:29  0f4e2a4b    ad campaign hit  0.595833         0.0

# %%
cantidad_eventos_usuario = sesiones.groupby(['person', 'session_id'])['event']\
    .value_counts().unstack().unstack().sum(axis=1).to_frame().rename(columns={0:"total_eventos"})

# %%
cantidad_eventos_usuario.head()
# Out:
#           total_eventos
# person
# 0008ed71            6.0
# 00091926          448.0
# 00091a7a           10.0
# 000ba417          206.0
# 000c79fe           17.0

# %%
sesiones_por_usuario = sesiones.groupby('person')['session_id'].unique().apply(lambda x: len(x)).\
                        to_frame().rename(columns={'session_id':'total_sesiones'})
promedio_eventos_sesion = cantidad_eventos_usuario.join(sesiones_por_usuario)

# %%
promedio_eventos_sesion['promedio_eventos_por_sesion'] = promedio_eventos_sesion['total_eventos']\
                                            / promedio_eventos_sesion['total_sesiones']

# %%
user_features = user_features.join(promedio_eventos_sesion[['total_sesiones', 'promedio_eventos_por_sesion']])

# %%
user_features.fillna(0, inplace=True)

# %%
user_features.to_csv('data/features_basicas.csv', sep=',')

# %%
user_features
# Out:
#           cant_conversions  cant_checkouts  cant_viewed_product  \
# person
# 4886f805               0.0             1.0                  4.0
# ad93850f               0.0             1.0                 20.0
# 0297fc1e               0.0             7.0                404.0
# 2d681dd8               0.0             1.0                 13.0
# cccea85e               0.0             1.0                739.0
# 4c8a8b93               0.0             2.0                177.0
# 1b9f7cf6               0.0             1.0                  9.0
# 29ebb414               0.0             1.0                  8.0
# de8fe91b               0.0             1.0                 27.0
# 45baf068               0.0             1.0                  6.0
# 99abca5a               2.0            18.0                630.0
# 3dc1950f               0.0             3.0                595.0
# 8ea4c165               0.0             3.0                 97.0
# 64f45e8d               0.0             2.0                 32.0
# d8cfe234               1.0             3.0                 39.0
# ade6b3bf               0.0             1.0                 92.0
# d73ae9ef               0.0             1.0                  5.0
# d6bc64df               0.0             2.0                155.0
# ec9c4059               1.0             2.0                 25.0
# b2cde41a               0.0             1.0                 27.0
# 15ea8012               5.0             4.0                 23.0
# 43790d8f               0.0             2.0                 62.0
# d21b8e6b               0.0             2.0                  5.0
# 2a724d87               0.0             1.0                  1.0
# 429c8732               0.0             3.0               1075.0
# 686c49c9               0.0             0.0                 19.0
# 4e03ed9a               0.0             1.0                  4.0
# a08d42ea               1.0             1.0                 41.0
# 16fad36a               0.0             7.0               1300.0
# be32e904               0.0             2.0                  8.0
# ...                    ...             ...                  ...
# 154d2935               0.0             0.0                  0.0
# 3adf7ca4               0.0             0.0                  0.0
# c9552fad               0.0             0.0                  0.0
# 2e89874a               0.0             0.0                  0.0
# ef4e52ab               0.0             0.0                  0.0
# 100f33c8               0.0             0.0                  0.0
# 90251b6a               0.0             0.0                  0.0
# 85e0f62a               0.0             0.0                  0.0
# 0afaecc8               0.0             0.0                  0.0
# 2c209f87               0.0             0.0                  0.0
# 4ddb8c19               0.0             0.0                  0.0
# 9979305a               0.0             0.0                  0.0
# 25bd8078               0.0             0.0                  0.0
# 87d306fc               0.0             0.0                  0.0
# a2b1e355               0.0             0.0                  0.0
# fb88a7ea               0.0             0.0                  0.0
# 1315ce31               0.0             0.0                  0.0
# af3374ad               0.0             0.0                  0.0
# 023581f9               0.0             0.0                  0.0
# 9707cd0e               0.0             0.0                  0.0
# 88b91c5d               0.0             0.0                  0.0
# 6f7632db               0.0             0.0                  0.0
# a1c2a901               0.0             0.0                  0.0
# ed3f80d7               0.0             0.0                  0.0
# 2adb3684               0.0             0.0                  0.0
# 39fa45b6               0.0             0.0                  0.0
# 92f2d94b               0.0             0.0                  0.0
# d8d6b0da               0.0             0.0                  0.0
# 40bf23ab               0.0             0.0                  0.0
# 80aea0a0               0.0             0.0                  0.0
#
#           cant_searched_product  cant_ad_campaign_hit  ad_campaign_hit  \
# person
# 4886f805                    1.0                   0.0            False
# ad93850f                    0.0                  10.0             True
# 0297fc1e                    6.0                  29.0             True
# 2d681dd8                    1.0                   1.0             True
# cccea85e                    1.0                  15.0             True
# 4c8a8b93                    9.0                  14.0             True
# 1b9f7cf6                    8.0                   0.0            False
# 29ebb414                   11.0                   4.0             True
# de8fe91b                   13.0                   0.0            False
# 45baf068                    0.0                   5.0             True
# 99abca5a                    5.0                  12.0             True
# 3dc1950f                    2.0                   3.0             True
# 8ea4c165                   17.0                  13.0             True
# 64f45e8d                    1.0                   1.0             True
# d8cfe234                    8.0                   0.0            False
# ade6b3bf                    5.0                  13.0             True
# d73ae9ef                    0.0                   0.0            False
# d6bc64df                   19.0                  10.0             True
# ec9c4059                    9.0                  17.0             True
# b2cde41a                    0.0                   1.0             True
# 15ea8012                    6.0                   7.0             True
# 43790d8f                    0.0                   2.0             True
# d21b8e6b                    3.0                   2.0             True
# 2a724d87                    0.0                   1.0             True
# 429c8732                   12.0                  69.0             True
# 686c49c9                    0.0                   0.0            False
# 4e03ed9a                    0.0                   6.0             True
# a08d42ea                    0.0                   2.0             True
# 16fad36a                    0.0                  58.0             True
# be32e904                    9.0                   1.0             True
# ...                         ...                   ...              ...
# 154d2935                    0.0                   0.0            False
# 3adf7ca4                    0.0                   0.0            False
# c9552fad                    0.0                   0.0            False
# 2e89874a                    0.0                   0.0            False
# ef4e52ab                    0.0                   0.0            False
# 100f33c8                    0.0                   0.0            False
# 90251b6a                    0.0                   0.0            False
# 85e0f62a                    0.0                   0.0            False
# 0afaecc8                    0.0                   0.0            False
# 2c209f87                    0.0                   0.0            False
# 4ddb8c19                    0.0                   0.0            False
# 9979305a                    0.0                   0.0            False
# 25bd8078                    0.0                   0.0            False
# 87d306fc                    0.0                   0.0            False
# a2b1e355                    0.0                   0.0            False
# fb88a7ea                    0.0                   0.0            False
# 1315ce31                    0.0                   0.0            False
# af3374ad                    0.0                   0.0            False
# 023581f9                    0.0                   0.0            False
# 9707cd0e                    0.0                   0.0            False
# 88b91c5d                    0.0                   0.0            False
# 6f7632db                    0.0                   0.0            False
# a1c2a901                    0.0                   0.0            False
# ed3f80d7                    0.0                   0.0            False
# 2adb3684                    0.0                   0.0            False
# 39fa45b6                    0.0                   0.0            False
# 92f2d94b                    0.0                   0.0            False
# d8d6b0da                    0.0                   0.0            False
# 40bf23ab                    0.0                   0.0            False
# 80aea0a0                    0.0                   0.0            False
#
#           cant_lead  cant_brand_listing  brand listing  total_sesiones  \
# person
# 4886f805        0.0                 0.0          False               1
# ad93850f        0.0                15.0           True               5
# 0297fc1e        1.0                 4.0           True              89
# 2d681dd8        0.0                 5.0           True               2
# cccea85e        0.0                 7.0           True              17
# 4c8a8b93        0.0                 8.0           True              14
# 1b9f7cf6        0.0                 3.0           True               3
# 29ebb414        0.0                 0.0          False               4
# de8fe91b        0.0                 3.0           True               2
# 45baf068        0.0                 3.0           True               1
# 99abca5a        1.0                30.0           True              49
# 3dc1950f        0.0                 6.0           True              27
# 8ea4c165        0.0                 5.0           True               7
# 64f45e8d        0.0                 1.0           True               3
# d8cfe234        0.0                 4.0           True               5
# ade6b3bf        0.0                 3.0           True              12
# d73ae9ef        0.0                 4.0           True               1
# d6bc64df        0.0                 0.0          False               6
# ec9c4059        0.0                 2.0           True               7
# b2cde41a        0.0                 0.0          False               4
# 15ea8012        0.0                 0.0          False               3
# 43790d8f        0.0                 0.0          False               2
# d21b8e6b        0.0                 0.0          False               1
# 2a724d87        0.0                 1.0           True               1
# 429c8732        0.0               108.0           True              53
# 686c49c9        0.0                 6.0           True               3
# 4e03ed9a        0.0                 3.0           True               4
# a08d42ea        0.0                 0.0          False               4
# 16fad36a        0.0                 6.0           True              55
# be32e904        0.0                 0.0          False               1
# ...             ...                 ...            ...             ...
# 154d2935        0.0                 0.0          False               1
# 3adf7ca4        0.0                 4.0           True               3
# c9552fad        0.0                 0.0          False               2
# 2e89874a        0.0                 0.0          False               1
# ef4e52ab        0.0                 0.0          False               1
# 100f33c8        0.0                 3.0           True               2
# 90251b6a        0.0                 0.0          False               1
# 85e0f62a        0.0                13.0           True               3
# 0afaecc8        0.0                 0.0          False               1
# 2c209f87        0.0                 0.0          False               3
# 4ddb8c19        0.0                 0.0          False               1
# 9979305a        0.0                 0.0          False              14
# 25bd8078        0.0                 0.0          False               7
# 87d306fc        0.0                 0.0          False               5
# a2b1e355        0.0                 0.0          False               1
# fb88a7ea        0.0                 0.0          False               1
# 1315ce31        0.0                 0.0          False              10
# af3374ad        0.0                 0.0          False               2
# 023581f9        0.0                 0.0          False               1
# 9707cd0e        0.0                 0.0          False               1
# 88b91c5d        0.0                 0.0          False               1
# 6f7632db        0.0                 0.0          False               1
# a1c2a901        0.0                 0.0          False               1
# ed3f80d7        0.0                 0.0          False               1
# 2adb3684        0.0                 0.0          False               1
# 39fa45b6        0.0                 0.0          False               1
# 92f2d94b        1.0                 0.0          False               1
# d8d6b0da        1.0                 0.0          False               1
# 40bf23ab        1.0                 0.0          False               1
# 80aea0a0        1.0                 0.0          False               1
#
#           promedio_eventos_por_sesion
# person
# 4886f805                     9.000000
# ad93850f                    13.000000
# 0297fc1e                     6.370787
# 2d681dd8                    13.000000
# cccea85e                    49.176471
# 4c8a8b93                    18.357143
# 1b9f7cf6                     8.333333
# 29ebb414                     8.750000
# de8fe91b                    26.500000
# 45baf068                    20.000000
# 99abca5a                    16.714286
# 3dc1950f                    24.888889
# 8ea4c165                    22.714286
# 64f45e8d                    15.666667
# d8cfe234                    12.400000
# ade6b3bf                    11.583333
# d73ae9ef                    17.000000
# d6bc64df                    35.500000
# ec9c4059                    14.000000
# b2cde41a                     9.250000
# 15ea8012                    25.000000
# 43790d8f                    38.000000
# d21b8e6b                    13.000000
# 2a724d87                     7.000000
# 429c8732                    25.943396
# 686c49c9                    11.666667
# 4e03ed9a                     6.250000
# a08d42ea                    14.750000
# 16fad36a                    27.890909
# be32e904                    23.000000
# ...                               ...
# 154d2935                     1.000000
# 3adf7ca4                     3.666667
# c9552fad                     2.000000
# 2e89874a                     1.000000
# ef4e52ab                     2.000000
# 100f33c8                     2.500000
# 90251b6a                     2.000000
# 85e0f62a                     5.666667
# 0afaecc8                     1.000000
# 2c209f87                     1.000000
# 4ddb8c19                     1.000000
# 9979305a                     1.071429
# 25bd8078                     1.000000
# 87d306fc                     1.000000
# a2b1e355                     1.000000
# fb88a7ea                     1.000000
# 1315ce31                     1.000000
# af3374ad                     1.000000
# 023581f9                     1.000000
# 9707cd0e                     1.000000
# 88b91c5d                     1.000000
# 6f7632db                     1.000000
# a1c2a901                     1.000000
# ed3f80d7                     1.000000
# 2adb3684                     1.000000
# 39fa45b6                     1.000000
# 92f2d94b                     1.000000
# d8d6b0da                     1.000000
# 40bf23ab                     1.000000
# 80aea0a0                     1.000000
#
# [38829 rows x 11 columns]
