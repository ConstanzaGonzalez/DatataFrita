# %%
# importacion general de librerias y de visualizacion (matplotlib y seaborn)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.style.use('default') # haciendo los graficos un poco mas bonitos en matplotlib
#plt.rcParams['figure.figsize'] = (20, 10)

sns.set(style="whitegrid") # seteando tipo de grid en seaborn

# %%
types= {
    "event": "category", 
    "model": "category", 
    "condition": "category", 
    "color": "category", 
    "storage": "category"
}
df_events = pd.read_csv('./fiuba-trocafone-tp1-final-set/events.csv', dtype=types, low_memory=False)

# %%
df_events[['campaign_source','search_engine', 'device_type', 'new_vs_returning']].head(20)
# Out:
#    campaign_source search_engine device_type new_vs_returning
# 0           criteo           NaN         NaN              NaN
# 1              NaN           NaN  Smartphone              New
# 2              NaN           NaN         NaN              NaN
# 3              NaN           NaN         NaN              NaN
# 4              NaN           NaN         NaN              NaN
# 5              NaN           NaN  Smartphone              New
# 6           criteo           NaN         NaN              NaN
# 7              NaN           NaN         NaN              NaN
# 8              NaN           NaN         NaN              NaN
# 9              NaN           NaN    Computer              New
# 10             NaN        Google         NaN              NaN
# 11          google           NaN         NaN              NaN
# 12             NaN           NaN         NaN              NaN
# 13             NaN           NaN         NaN              NaN
# 14             NaN           NaN         NaN              NaN
# 15          google           NaN         NaN              NaN
# 16             NaN           NaN    Computer        Returning
# 17             NaN        Google         NaN              NaN
# 18             NaN           NaN         NaN              NaN
# 19             NaN           NaN         NaN              NaN

# %%
users1 = df_events[["new_vs_returning", "person", "event", "campaign_source", "search_engine", "device_type"]]

# %%
users1["person"].value_counts()
# Out:
# 71492f2b    2771
# 6b07be7b    2770
# 285101a1    2140
# 3e34b3cf    1877
# 2d5a84c1    1800
# 5f25cb5d    1797
# 5af7e2bc    1773
# 3b5a5833    1705
# d7e60792    1352
# cd6e0b8d    1254
# d9251b63    1234
# c501ff3a    1201
# 778fcfbd    1195
# a7d3181e    1185
# e2b0ce1b    1168
# c38d5de3    1162
# 6d2fe2db    1110
# 88cabe99    1073
# ba102035    1014
# ff9dc4b8    1005
# b7db0194    1003
# a94ab0df     990
# e27ec493     978
# 55d9fd71     973
# 8e0c69f6     958
# 63112254     955
# d5661793     950
# badaab79     930
# 3444791f     913
# 9fdfd942     907
#             ...
# 8f3d8825       1
# c2929d24       1
# 9bbc8ca1       1
# d043ee75       1
# 76046086       1
# 74068913       1
# 4dc43d43       1
# 2e16f052       1
# cb9a1197       1
# fdbe5136       1
# e7eb9ac2       1
# 759683a2       1
# f5cfcef8       1
# 09675dc1       1
# f814cc35       1
# ca5a2f18       1
# f107a1a7       1
# 321d1f1d       1
# ef8735af       1
# 6d87457e       1
# d8f0019e       1
# 4da04c89       1
# 5c0ab066       1
# fb454676       1
# 040cfd47       1
# a20ecf2c       1
# 6d8a8a1f       1
# 9b427216       1
# 303d311b       1
# ec2c084e       1
# Name: person, Length: 27624, dtype: int64

# %%
users2 = users1.loc[(users1["event"] == "ad campaign hit") & (users1["campaign_source"] == "google")]

# %%
users2["person"].value_counts()
# Out:
# a202cfba    275
# c013417a    210
# e2b0ce1b    131
# 0b2bff0b    110
# 8fb99250    105
# f3c1111e    105
# 875eb866     94
# 3952fd6f     94
# 5af7e2bc     94
# 4f50d6c5     91
# 8ade1780     86
# 95b58cd6     86
# d9251b63     78
# a1e1f8ec     75
# 14752aa3     73
# 1a959985     72
# e32aadb9     67
# cc4f129e     67
# d85fbcc9     65
# 73eeb9a2     63
# 5d40cd8b     63
# ba102035     62
# 3444791f     62
# 079290c6     62
# ddd5ae61     62
# 0928c785     62
# f67477ae     60
# 5dbdee43     59
# 778fcfbd     59
# 8059b958     58
#            ...
# 85e1287e      1
# bb1912d0      1
# bd3b2545      1
# 56c33c84      1
# bebfbd88      1
# 959ec16b      1
# 689acc0d      1
# 2ac0c5ca      1
# 1d2e3564      1
# 2f8a1c76      1
# b447e66a      1
# 784ac11b      1
# af5615b0      1
# e2c0188b      1
# 9ce19678      1
# 00344c0a      1
# 231eab40      1
# ca0d7b24      1
# fff60213      1
# b106e0c9      1
# 54dbafde      1
# 11950bd9      1
# ff2efe3e      1
# 7a8fd046      1
# 929eceae      1
# ff0dc7e5      1
# a66f2b2a      1
# f57f5000      1
# 44a63195      1
# ece4daeb      1
# Name: person, Length: 17372, dtype: int64

# %%
#Cantidad de personas que visitan la pagina mediante una computadora
filter_col = df_events[[ "person", "event", "device_type"]]
filter_row = filter_col.loc[(filter_col["event"] == "visited site") & (filter_col["device_type"] == "Computer")]

# %%
filter_row
# Out:
#            person         event device_type
# 9        000a54b2  visited site    Computer
# 16       000a54b2  visited site    Computer
# 45       00184bf9  visited site    Computer
# 87       00184bf9  visited site    Computer
# 106      001bb7eb  visited site    Computer
# 108      001bb7eb  visited site    Computer
# 116      00204059  visited site    Computer
# 118      00204059  visited site    Computer
# 127      00204059  visited site    Computer
# 144      00204059  visited site    Computer
# 154      00204059  visited site    Computer
# 168      00204059  visited site    Computer
# 175      00204059  visited site    Computer
# 190      00204059  visited site    Computer
# 203      00204059  visited site    Computer
# 206      00204059  visited site    Computer
# 210      00204059  visited site    Computer
# 221      00204059  visited site    Computer
# 227      0024a82b  visited site    Computer
# 235      0024ad28  visited site    Computer
# 244      0024ad28  visited site    Computer
# 252      0024ad28  visited site    Computer
# 272      0026fd72  visited site    Computer
# 274      0026fd72  visited site    Computer
# 302      0027c344  visited site    Computer
# 307      0027c344  visited site    Computer
# 312      0027c344  visited site    Computer
# 362      002cecfa  visited site    Computer
# 369      00300ace  visited site    Computer
# 374      00300ace  visited site    Computer
# ...           ...           ...         ...
# 1010769  ffd0be6e  visited site    Computer
# 1010803  ffd9b5f9  visited site    Computer
# 1010839  ffdcf469  visited site    Computer
# 1010865  ffe006ea  visited site    Computer
# 1010874  ffe006ea  visited site    Computer
# 1010890  ffe1bfe7  visited site    Computer
# 1010938  ffe1bfe7  visited site    Computer
# 1010949  ffe1f855  visited site    Computer
# 1010986  ffe226f0  visited site    Computer
# 1011011  ffe741db  visited site    Computer
# 1011018  ffeaaa70  visited site    Computer
# 1011027  ffeaaa70  visited site    Computer
# 1011036  ffeaaa70  visited site    Computer
# 1011045  ffeb3a03  visited site    Computer
# 1011049  ffeb3a03  visited site    Computer
# 1011055  ffef9da6  visited site    Computer
# 1011060  fff0e00c  visited site    Computer
# 1011064  fff0e00c  visited site    Computer
# 1011127  fff0e00c  visited site    Computer
# 1011148  fff0e00c  visited site    Computer
# 1011190  fff229f7  visited site    Computer
# 1011200  fff229f7  visited site    Computer
# 1011206  fff568f7  visited site    Computer
# 1011208  fff568f7  visited site    Computer
# 1011221  fff568f7  visited site    Computer
# 1011236  fff99b85  visited site    Computer
# 1011251  ffffa8d1  visited site    Computer
# 1011258  ffffa8d1  visited site    Computer
# 1011273  ffffa8d1  visited site    Computer
# 1011277  ffffa8d1  visited site    Computer
#
# [41790 rows x 3 columns]

# %%
#Cantidad de personas que visitan la pagina mediante un smartphone
filter_row = filter_col.loc[(filter_col["event"] == "visited site") ]
filter_row["device_type"].value_counts()
# Out:
# Smartphone    44239
# Computer      41790
# Tablet         1234
# Unknown         115
# Name: device_type, dtype: int64

# %%
#filter_row.loc[(filter_row["device_type"] == "Unknown")]
filter_row
# Out:
#            person         event device_type
# 1        0004b0a2  visited site  Smartphone
# 5        0006a21a  visited site  Smartphone
# 9        000a54b2  visited site    Computer
# 16       000a54b2  visited site    Computer
# 45       00184bf9  visited site    Computer
# 87       00184bf9  visited site    Computer
# 96       0019c395  visited site  Smartphone
# 106      001bb7eb  visited site    Computer
# 108      001bb7eb  visited site    Computer
# 112      001f1653  visited site  Smartphone
# 116      00204059  visited site    Computer
# 118      00204059  visited site    Computer
# 127      00204059  visited site    Computer
# 144      00204059  visited site    Computer
# 154      00204059  visited site    Computer
# 168      00204059  visited site    Computer
# 175      00204059  visited site    Computer
# 190      00204059  visited site    Computer
# 203      00204059  visited site    Computer
# 206      00204059  visited site    Computer
# 210      00204059  visited site    Computer
# 221      00204059  visited site    Computer
# 227      0024a82b  visited site    Computer
# 235      0024ad28  visited site    Computer
# 244      0024ad28  visited site    Computer
# 252      0024ad28  visited site    Computer
# 258      00269e77  visited site  Smartphone
# 261      00269e77  visited site  Smartphone
# 266      00269e77  visited site  Smartphone
# 268      00269e77  visited site  Smartphone
# ...           ...           ...         ...
# 1010880  ffe129fe  visited site  Smartphone
# 1010890  ffe1bfe7  visited site    Computer
# 1010938  ffe1bfe7  visited site    Computer
# 1010949  ffe1f855  visited site    Computer
# 1010986  ffe226f0  visited site    Computer
# 1011011  ffe741db  visited site    Computer
# 1011018  ffeaaa70  visited site    Computer
# 1011027  ffeaaa70  visited site    Computer
# 1011036  ffeaaa70  visited site    Computer
# 1011045  ffeb3a03  visited site    Computer
# 1011049  ffeb3a03  visited site    Computer
# 1011055  ffef9da6  visited site    Computer
# 1011060  fff0e00c  visited site    Computer
# 1011064  fff0e00c  visited site    Computer
# 1011127  fff0e00c  visited site    Computer
# 1011148  fff0e00c  visited site    Computer
# 1011181  fff225f8  visited site  Smartphone
# 1011190  fff229f7  visited site    Computer
# 1011200  fff229f7  visited site    Computer
# 1011206  fff568f7  visited site    Computer
# 1011208  fff568f7  visited site    Computer
# 1011221  fff568f7  visited site    Computer
# 1011232  fff60213  visited site  Smartphone
# 1011236  fff99b85  visited site    Computer
# 1011243  ffff8106  visited site      Tablet
# 1011251  ffffa8d1  visited site    Computer
# 1011258  ffffa8d1  visited site    Computer
# 1011273  ffffa8d1  visited site    Computer
# 1011277  ffffa8d1  visited site    Computer
# 1011284  ffffac8a  visited site  Smartphone
#
# [87378 rows x 3 columns]

# %%
filter = (filter_row.loc[(filter_row["device_type"] != "Unknown")])["device_type"].value_counts()
#filter_row = filter_row["device_type"].value_counts()
filter
# Out:
# Smartphone    44239
# Computer      41790
# Tablet         1234
# Name: device_type, dtype: int64

# %%
ax = filter.plot.pie(title = "Dispositivos mas utilizados para visitar la página", figsize =(7,7), colors = ['#66b3ff','#ff6666','#99ff99'], legend = False, fontsize = 12 )
plt.show()
