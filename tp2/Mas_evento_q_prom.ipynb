# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/events_up_to_01062018.csv', low_memory=False)
df['timestamp'] = pd.to_datetime(df['timestamp'])
df.head()
# Out:
#             timestamp           event    person  url      sku  \
# 0 2018-05-18 00:11:59  viewed product  4886f805  NaN   9288.0
# 1 2018-05-18 00:11:27  viewed product  ad93850f  NaN    304.0
# 2 2018-05-18 00:11:16  viewed product  0297fc1e  NaN   6888.0
# 3 2018-05-18 00:11:14  viewed product  2d681dd8  NaN  11890.0
# 4 2018-05-18 00:11:09  viewed product  cccea85e  NaN   7517.0
#
#                      model  condition storage           color skus  \
# 0  Samsung Galaxy J7 Prime  Excelente    32GB         Dourado  NaN
# 1                iPhone 5s  Muito Bom    32GB  Cinza espacial  NaN
# 2                iPhone 6S  Muito Bom    64GB        Prateado  NaN
# 3                 iPhone 7        Bom   128GB        Vermelho  NaN
# 4              LG G4 H818P  Excelente    32GB          Branco  NaN
#
#         ...       search_engine channel new_vs_returning city region country  \
# 0       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# ...

# %% [markdown]
# ### cantidad de eventos antes de hacer una conversion

# %%
df2 = df[df["event"]=="viewed product"]
df2 = df2.groupby('person')['event'].value_counts().unstack()
df2.rename(columns={"viewed product":'cant_view_prodc'}, inplace=True)

# %%
df_prom = df2.groupby("person").agg({"cant_view_prodc":"mean"})
prom = df2.agg({"cant_view_prodc":"mean"})

df_prom["mas_prom"] = df_prom["cant_view_prodc"].apply(lambda x: 1 if x > prom.values[0] else 0)
#df_prom = df_prom.drop("cant_view_prodc",1)

# %%
df_prom.to_csv('data/vistas_promedio.csv', sep=',')

# %% [markdown]
# compradores = df.loc[df['event'] == "conversion"]
# compradores = compradores["person"].drop_duplicates().tolist()

# %% [markdown]
# data = df.loc[(df["person"].isin(compradores))]
# #(df["event"]!= "conversion") &
# data = data.groupby("person")["event"].value_counts().to_frame()
# data.columns = ['cant']
# data.reset_index()

# %%
df_prom
# Out:
#           cant_view_prodc  mas_prom
# person
# 00091926              372         1
# 00091a7a                3         0
# 000ba417              153         1
# 000c79fe                3         0
# 000e4d9e              339         1
# 000e619d               28         0
# 001001be               41         1
# 0010e89a                1         0
# 0016c4b5                1         0
# 001802e4                4         0
# 0019e639              189         1
# 001a2273                6         0
# 001b0bf9                2         0
# 001ca5ee               52         1
# 001dfc31               18         0
# 001e9aea               17         0
# 0020152e                2         0
# 00202cdb               14         0
# 0022965d               15         0
# 0027574e              102         1
# 00295d74               11         0
# 002aea56              161         1
# 002b0188               12         0
# 002e74b2                2         0
# 002ed810               22         0
# ...
