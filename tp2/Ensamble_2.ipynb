# %%
import pandas as pd
import numpy as np

# %%
sub_rf = pd.read_csv("submit/submit_clf.csv", low_memory=False)
sub = pd.read_csv("submit/submit_xg_2_2.csv", low_memory=False)
sub_xgb = pd.read_csv("submit/submit_xg_2_1.csv", low_memory=False)
user = sub_rf["person"].to_frame()

# %%
label = ((sub["label"]+sub_xgb["label"]+sub_rf["label"]))/3
user["label"] = label.values
user = user.set_index("person")

# %%
user.to_csv("submit/ensamble_random.csv",sep=",")

# %%
user
# Out:
#              label
# person
# 4886f805  0.020647
# 0297fc1e  0.194519
# 2d681dd8  0.023080
# cccea85e  0.183045
# 4c8a8b93  0.082242
# 29ebb414  0.046161
# 3dc1950f  0.157419
# 8ea4c165  0.099973
# d8cfe234  0.103128
# d6bc64df  0.113824
# ec9c4059  0.090237
# d21b8e6b  0.018490
# 2a724d87  0.018158
# 686c49c9  0.369487
# a08d42ea  0.073814
# c98f5cf1  0.167047
# d614c608  0.031617
# e45acd53  0.399156
# 7d876393  0.123842
# f5af843f  0.139379
# 5a724794  0.090258
# 00091926  0.155486
# 55d1e0ee  0.110267
# f87be219  0.019964
# 49c19e32  0.071489
# bb78c182  0.020669
# e2bfe05f  0.012679
# 0e9d0ae2  0.023361
# cb68850c  0.028918
# f30ef764  0.029831
# ...            ...
# 523c7e69  0.199636
# d2e564cb  0.310873
# eb27e544  0.300008
# b32e7113  0.270455
# a65f2cf0  0.232554
# a70b9f00  0.598449
# a161fd76  0.330698
# e9a4d3a8  0.224917
# 24f53ba2  0.205787
# 39cf8fa0  0.283525
# 9ceab28a  0.292594
# f85da107  0.287081
# 154d2935  0.261047
# 3adf7ca4  0.289864
# 2e89874a  0.265955
# ...

# %%
user["label"].mean()
# Out:
# 0.12586366578647532

# %%
0.12713147548822754
# Out:
# 0.12713147548822754

# %%
0.15896705882639883
