# %%
# importacion general de librerias y de visualizacion (matplotlib y seaborn)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

plt.style.use('default') # haciendo los graficos un poco mas bonitos en matplotlib
#plt.rcParams['figure.figsize'] = (20, 10)

sns.set(style="whitegrid") # seteando tipo de grid en seaborn

# %%
types= {
    "event": "category", 
    "model": "category", 
    "condition": "category", 
    "color": "category", 
    "storage": "category"
}
df_events = pd.read_csv('./fiuba-trocafone-tp1-final-set/events.csv', dtype=types, low_memory=False)

# %%
#Cantidad de campaign y de search engine
filter_colum = df_events[["person", "event", "campaign_source", "search_engine", "timestamp"]]
filter_colum
# Out:
#            person              event campaign_source search_engine  \
# 0        0004b0a2    ad campaign hit          criteo           NaN
# 1        0004b0a2       visited site             NaN           NaN
# 2        0004b0a2     viewed product             NaN           NaN
# 3        0004b0a2           checkout             NaN           NaN
# 4        0006a21a     viewed product             NaN           NaN
# 5        0006a21a       visited site             NaN           NaN
# 6        0006a21a    ad campaign hit          criteo           NaN
# 7        0006a21a           checkout             NaN           NaN
# 8        000a54b2    generic listing             NaN           NaN
# 9        000a54b2       visited site             NaN           NaN
# 10       000a54b2  search engine hit             NaN        Google
# 11       000a54b2    ad campaign hit          google           NaN
# 12       000a54b2      brand listing             NaN           NaN
# 13       000a54b2     viewed product             NaN           NaN
# 14       000a54b2      brand listing             NaN           NaN
# 15       000a54b2    ad campaign hit          google           NaN
# 16       000a54b2       visited site             NaN           NaN
# 17       000a54b2  search engine hit             NaN        Google
# 18       000a54b2    generic listing             NaN           NaN
# 19       000a54b2    generic listing             NaN           NaN
# 20       000a54b2      brand listing             NaN           NaN
# 21       000a54b2    generic listing             NaN           NaN
# 22       000a54b2     viewed product             NaN           NaN
# 23       000a54b2    generic listing             NaN           NaN
# 24       000a54b2      brand listing             NaN           NaN
# 25       000a54b2      brand listing             NaN           NaN
# 26       000a54b2     viewed product             NaN           NaN
# 27       000a54b2     viewed product             NaN           NaN
# 28       000a54b2     viewed product             NaN           NaN
# 29       000a54b2     viewed product             NaN           NaN
# ...           ...                ...             ...           ...
# 1011258  ffffa8d1       visited site             NaN           NaN
# 1011259  ffffa8d1  search engine hit             NaN        Google
# 1011260  ffffa8d1    generic listing             NaN           NaN
# 1011261  ffffa8d1  searched products             NaN           NaN
# 1011262  ffffa8d1     viewed product             NaN           NaN
# 1011263  ffffa8d1     viewed product             NaN           NaN
# 1011264  ffffa8d1     viewed product             NaN           NaN
# 1011265  ffffa8d1     viewed product             NaN           NaN
# 1011266  ffffa8d1     viewed product             NaN           NaN
# 1011267  ffffa8d1     viewed product             NaN           NaN
# 1011268  ffffa8d1     viewed product             NaN           NaN
# 1011269  ffffa8d1     viewed product             NaN           NaN
# 1011270  ffffa8d1     viewed product             NaN           NaN
# 1011271  ffffa8d1     viewed product             NaN           NaN
# 1011272  ffffa8d1     viewed product             NaN           NaN
# 1011273  ffffa8d1       visited site             NaN           NaN
# 1011274  ffffa8d1    generic listing             NaN           NaN
# 1011275  ffffa8d1     viewed product             NaN           NaN
# 1011276  ffffa8d1  search engine hit             NaN        Google
hit_contains = filter_colum.loc[filter_colum["event"].str.contains("hit")]
hit_contains
# Out:
#            person              event campaign_source search_engine  \
# 0        0004b0a2    ad campaign hit          criteo           NaN
# 6        0006a21a    ad campaign hit          criteo           NaN
# 10       000a54b2  search engine hit             NaN        Google
# 11       000a54b2    ad campaign hit          google           NaN
# 15       000a54b2    ad campaign hit          google           NaN
# 17       000a54b2  search engine hit             NaN        Google
# 47       00184bf9  search engine hit             NaN        Google
# 62       00184bf9  search engine hit             NaN        Google
# 97       0019c395  search engine hit             NaN        Google
# 99       0019c395    ad campaign hit          google           NaN
# 100      0019c395  search engine hit             NaN        Google
# 101      0019c395    ad campaign hit          google           NaN
# 105      001bb7eb  search engine hit             NaN        Google
# 107      001bb7eb    ad campaign hit          google           NaN
# 111      001f1653    ad campaign hit          criteo           NaN
# 119      00204059    ad campaign hit     FacebookAds           NaN
# 132      00204059    ad campaign hit           zanox           NaN
# 135      00204059    ad campaign hit           zanox           NaN
# 139      00204059    ad campaign hit           zanox           NaN
# 141      00204059    ad campaign hit           zanox           NaN
# 143      00204059    ad campaign hit          google           NaN
# 145      00204059  search engine hit             NaN        Google
# 153      00204059  search engine hit             NaN        Google
# 228      0024a82b    ad campaign hit          google           NaN
# 236      0024ad28  search engine hit             NaN          Bing
# 245      0024ad28    ad campaign hit          criteo           NaN
# 247      0024ad28    ad campaign hit        rtbhouse           NaN
# 251      0024ad28    ad campaign hit          criteo           NaN
# 259      00269e77    ad campaign hit          criteo           NaN
# 260      00269e77    ad campaign hit          google           NaN
# ...           ...                ...             ...           ...
# 1011069  fff0e00c  search engine hit             NaN        Google
# 1011072  fff0e00c  search engine hit             NaN        Google
# 1011075  fff0e00c  search engine hit             NaN        Google
# 1011077  fff0e00c  search engine hit             NaN        Google
# 1011080  fff0e00c  search engine hit             NaN        Google
# 1011084  fff0e00c  search engine hit             NaN        Google
# 1011086  fff0e00c  search engine hit             NaN        Google
# 1011090  fff0e00c  search engine hit             NaN        Google
# 1011093  fff0e00c  search engine hit             NaN        Google
# 1011126  fff0e00c  search engine hit             NaN        Google
# 1011182  fff225f8    ad campaign hit          criteo           NaN
# 1011183  fff225f8    ad campaign hit          criteo           NaN
# 1011187  fff229f7  search engine hit             NaN        Google
# 1011189  fff229f7    ad campaign hit          google           NaN
# 1011199  fff229f7  search engine hit             NaN        Google
# 1011205  fff568f7  search engine hit             NaN        Google
# 1011210  fff568f7    ad campaign hit          criteo           NaN
# 1011222  fff568f7    ad campaign hit          google           NaN
# 1011223  fff568f7  search engine hit             NaN        Google
# 1011231  fff60213    ad campaign hit          google           NaN
# 1011235  fff99b85    ad campaign hit          google           NaN
# 1011241  ffff8106    ad campaign hit          google           NaN
# 1011242  ffff8106  search engine hit             NaN        Google
# 1011248  ffffa8d1    ad campaign hit          google           NaN
# 1011249  ffffa8d1  search engine hit             NaN        Google
# brand listing            0
# Name: event, dtype: int64

# %%
search["event"].value_counts()
# Out:
# search engine hit    50957
# visited site             0
# viewed product           0
# staticpage               0
# searched products        0
# lead                     0
# generic listing          0
# conversion               0
# checkout                 0
# brand listing            0
# ad campaign hit          0
# Name: event, dtype: int64

# %%
group = filter_colum.groupby(["person", "event"])
group.count()
# Out:
#                             campaign_source  search_engine  timestamp
# person   event
# 0004b0a2 ad campaign hit                1.0            0.0        1.0
#          brand listing                  NaN            NaN        NaN
#          checkout                       0.0            0.0        1.0
#          conversion                     NaN            NaN        NaN
#          generic listing                NaN            NaN        NaN
#          lead                           NaN            NaN        NaN
#          search engine hit              NaN            NaN        NaN
#          searched products              NaN            NaN        NaN
#          staticpage                     NaN            NaN        NaN
#          viewed product                 0.0            0.0        1.0
#          visited site                   0.0            0.0        1.0
# 0006a21a ad campaign hit                1.0            0.0        1.0
#          brand listing                  NaN            NaN        NaN
#          checkout                       0.0            0.0        1.0
#          conversion                     NaN            NaN        NaN
#          generic listing                NaN            NaN        NaN
#          lead                           NaN            NaN        NaN
#          search engine hit              NaN            NaN        NaN
#          searched products              NaN            NaN        NaN
#          staticpage                     NaN            NaN        NaN
#          viewed product                 0.0            0.0        1.0
#          visited site                   0.0            0.0        1.0
# 000a54b2 ad campaign hit                2.0            0.0        2.0
#          brand listing                  0.0            0.0        6.0
#          checkout                       0.0            0.0        1.0
#          conversion                     NaN            NaN        NaN
#          generic listing                0.0            0.0        5.0
#          lead                           NaN            NaN        NaN
#          search engine hit              0.0            2.0        2.0
#          searched products              NaN            NaN        NaN
# ...                                     ...            ...        ...
# ffff8106 conversion                     NaN            NaN        NaN
#          generic listing                0.0            0.0        1.0
#          lead                           NaN            NaN        NaN
#          search engine hit              0.0            1.0        1.0
#          searched products              NaN            NaN        NaN
#          staticpage                     NaN            NaN        NaN
#          viewed product                 0.0            0.0        3.0
#          visited site                   0.0            0.0        1.0
# ffffa8d1 ad campaign hit                3.0            0.0        3.0
#          brand listing                  NaN            NaN        NaN
#          checkout                       0.0            0.0        1.0
#          conversion                     NaN            NaN        NaN
#          generic listing                0.0            0.0        4.0
#          lead                           NaN            NaN        NaN
#          search engine hit              0.0            3.0        3.0
#          searched products              0.0            0.0        2.0
#          staticpage                     NaN            NaN        NaN
#          viewed product                 0.0            0.0       19.0
#          visited site                   0.0            0.0        4.0
# ffffac8a ad campaign hit                1.0            0.0        1.0
#          brand listing                  NaN            NaN        NaN
#          checkout                       0.0            0.0        1.0
#          conversion                     NaN            NaN        NaN
#          generic listing                NaN            NaN        NaN
#          lead                           NaN            NaN        NaN
#          search engine hit              NaN            NaN        NaN
#          searched products              NaN            NaN        NaN
#          staticpage                     NaN            NaN        NaN
#          viewed product                 0.0            0.0        1.0
#          visited site                   0.0            0.0        1.0
#
# [303864 rows x 3 columns]
