# %%
import pandas as pd
import numpy as np

# %%
sub_rf = pd.read_csv("submit_clf.csv", low_memory=False)
sub_xgb = pd.read_csv("submit_xg_2.csv", low_memory=False)
user = sub_rf["person"].to_frame()

# %%
label = ((sub_rf["label"]+sub_xgb["label"]))/2
user["label"] = label.values
user = user.set_index("person")

# %%
user.to_csv("ensamble.csv",sep=",")

# %%
user
# Out:
#              label
# person
# 4886f805  0.031020
# 0297fc1e  0.124609
# 2d681dd8  0.031020
# cccea85e  0.157753
# 4c8a8b93  0.094508
# 29ebb414  0.031020
# 3dc1950f  0.107714
# 8ea4c165  0.100943
# d8cfe234  0.064554
# d6bc64df  0.104061
# ec9c4059  0.109069
# d21b8e6b  0.031020
# 2a724d87  0.031020
# 686c49c9  0.333783
# a08d42ea  0.062940
# c98f5cf1  0.109923
# d614c608  0.031020
# e45acd53  0.207628
# 7d876393  0.096052
# f5af843f  0.108838
# 5a724794  0.113135
# 00091926  0.138134
# 55d1e0ee  0.110094
# f87be219  0.031020
# 49c19e32  0.061937
# bb78c182  0.031020
# e2bfe05f  0.031020
# 0e9d0ae2  0.031020
# cb68850c  0.031020
# f30ef764  0.031020
# ...            ...
# 523c7e69  0.188746
# d2e564cb  0.214852
# eb27e544  0.245841
# b32e7113  0.218050
# a65f2cf0  0.238232
# a70b9f00  0.267541
# a161fd76  0.197201
# e9a4d3a8  0.188746
# 24f53ba2  0.188746
# 39cf8fa0  0.197201
# 9ceab28a  0.200020
# f85da107  0.197850
# 154d2935  0.188746
# 3adf7ca4  0.289572
# 2e89874a  0.188746
# ...
