# %% [markdown]
# ## separar por mayor cantidad de telefonos vistos

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/events_up_to_01062018.csv', low_memory=False)
df.head()
# Out:
#              timestamp           event    person  url      sku  \
# 0  2018-05-18 00:11:59  viewed product  4886f805  NaN   9288.0
# 1  2018-05-18 00:11:27  viewed product  ad93850f  NaN    304.0
# 2  2018-05-18 00:11:16  viewed product  0297fc1e  NaN   6888.0
# 3  2018-05-18 00:11:14  viewed product  2d681dd8  NaN  11890.0
# 4  2018-05-18 00:11:09  viewed product  cccea85e  NaN   7517.0
#
#                      model  condition storage           color skus  \
# 0  Samsung Galaxy J7 Prime  Excelente    32GB         Dourado  NaN
# 1                iPhone 5s  Muito Bom    32GB  Cinza espacial  NaN
# 2                iPhone 6S  Muito Bom    64GB        Prateado  NaN
# 3                 iPhone 7        Bom   128GB        Vermelho  NaN
# 4              LG G4 H818P  Excelente    32GB          Branco  NaN
#
#         ...       search_engine channel new_vs_returning city region country  \
# 0       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# ...

# %%
df = df.loc[df["event"] == "viewed product"]
df["model_2"] = df["model"].apply(lambda x: x.split(" ")[0])
df_m = df.groupby("person")["model_2"].value_counts().to_frame()
df_m.columns = ['cant']
df_m = df_m.reset_index()
celulares = df_m["model_2"].value_counts()
celulares
#df_m
# Out:
# Samsung     24012
# iPhone      22934
# Motorola    11395
# LG           4226
# Sony         3056
# Lenovo       2306
# iPad         1676
# Asus         1218
# Quantum       792
# Name: model_2, dtype: int64

# %%
df_m = df_m.drop_duplicates(subset="person", keep='first')
df_m
# Out:
#          person   model_2  cant
# 0      00091926    iPhone   251
# 7      00091a7a    iPhone     3
# 8      000ba417   Samsung   105
# 13     000c79fe    iPhone     3
# 14     000e4d9e   Samsung   300
# 19     000e619d   Samsung    11
# 23     001001be    iPhone    41
# 24     0010e89a   Samsung     1
# 25     0016c4b5   Samsung     1
# 26     001802e4    iPhone     4
# 27     0019e639  Motorola   131
# 31     001a2273   Samsung     4
# 33     001b0bf9   Samsung     2
# 34     001ca5ee    iPhone    52
# 35     001dfc31    iPhone    17
# 37     001e9aea    iPhone    16
# 39     0020152e   Samsung     2
# 40     00202cdb    iPhone    14
# 41     0022965d   Samsung    15
# 42     0027574e   Samsung    75
# 46     00295d74   Samsung    11
# 47     002aea56    iPhone   137
# 53     002b0188   Samsung     9
# 57     002e74b2    iPhone     2
# 58     002ed810   Samsung    19
# 60     002fb981    iPhone    20
# 61     00317e49    iPhone     3
# 63     0031c75f  Motorola    16
# ...

# %%
df_m["vio_mas_apple"] = df_m["model_2"].apply(lambda x: 1 if x == "iPhone" else 0)
df_m["vio_mas_samsung"] = df_m["model_2"].apply(lambda x: 1 if x == "Samsung" else 0)
df_m["vio_mas_motorola"] = df_m["model_2"].apply(lambda x: 1 if x == "Motorola" else 0)
#df_m["vio_mas_lg"] = df_m["model_2"].apply(lambda x: 1 if x == "LG" else 0)
df_m = df_m.set_index("person")

# %%
df_m = df_m.drop(["model_2","cant"],1)

df_m.to_csv('data/features_mas_vistos.csv', sep=',')

# %%
df_m
# Out:
#           vio_mas_apple  vio_mas_samsung  vio_mas_motorola
# person
# 00091926              1                0                 0
# 00091a7a              1                0                 0
# 000ba417              0                1                 0
# 000c79fe              1                0                 0
# 000e4d9e              0                1                 0
# 000e619d              0                1                 0
# 001001be              1                0                 0
# 0010e89a              0                1                 0
# 0016c4b5              0                1                 0
# 001802e4              1                0                 0
# 0019e639              0                0                 1
# 001a2273              0                1                 0
# 001b0bf9              0                1                 0
# 001ca5ee              1                0                 0
# 001dfc31              1                0                 0
# ...
