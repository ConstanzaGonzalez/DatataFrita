# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/events_up_to_01062018.csv', low_memory=False)
df['timestamp'] = pd.to_datetime(df['timestamp'])
df.drop_duplicates("person")
# Out:
#                   timestamp              event    person  url      sku  \
# 0       2018-05-18 00:11:59     viewed product  4886f805  NaN   9288.0
# 1       2018-05-18 00:11:27     viewed product  ad93850f  NaN    304.0
# 2       2018-05-18 00:11:16     viewed product  0297fc1e  NaN   6888.0
# 3       2018-05-18 00:11:14     viewed product  2d681dd8  NaN  11890.0
# 4       2018-05-18 00:11:09     viewed product  cccea85e  NaN   7517.0
# 5       2018-05-18 00:44:27  searched products  4c8a8b93  NaN      NaN
# 6       2018-05-18 00:44:14     viewed product  1b9f7cf6  NaN   2831.0
# 7       2018-05-18 00:44:02     viewed product  29ebb414  NaN   2845.0
# 8       2018-05-18 00:43:59     viewed product  de8fe91b  NaN  12548.0
# 9       2018-05-18 00:43:40    ad campaign hit  45baf068    /      NaN
# 10      2018-05-18 00:42:14     viewed product  99abca5a  NaN  12536.0
# 11      2018-05-18 00:41:00     viewed product  3dc1950f  NaN  10407.0
# ...

# %%
test = df.loc[df["country"] != "Unknown"]
test = test.groupby("person")["country"].value_counts().to_frame()
test.columns = ['cant_de_apa']
test = test.reset_index()
test = test.drop("cant_de_apa",1)
test
# Out:
#          person  country
# 0      0008ed71   Brazil
# 1      00091926   Brazil
# 2      00091a7a   Brazil
# 3      000ba417   Brazil
# 4      000c79fe   Brazil
# 5      000e4d9e   Brazil
# 6      000e619d   Brazil
# 7      001001be   Brazil
# 8      0010e89a   Brazil
# 9      0016c4b5   Brazil
# 10     001802e4   Brazil
# 11     001804a2   Brazil
# 12     0019e639   Brazil
# 13     001a2273   Brazil
# 14     001ca5ee   Brazil
# 15     001dfc31   Brazil
# 16     001e9aea   Brazil
# 17     0020152e   Brazil
# 18     00202cdb   Brazil
# 19     0022965d   Brazil
# 20     0027574e   Brazil
# 21     00295d74   Brazil
# 22     002aea56   Brazil
# 23     002b0188   Brazil
# 24     002e74b2   Brazil
# 25     002ed810   Brazil
# 26     002fb981   Brazil
# 27     00317e49   Brazil
# 28     0031c75f   Brazil
# 29     00344873   Brazil
# ...         ...      ...
# 37560  ffc670b3   Brazil
# 37561  ffcaae19   Brazil
# 37562  ffcaeaae   Brazil
# 37563  ffccd5a1   Brazil
# 37564  ffcf952b   Brazil
# ...

# %%
test = pd.get_dummies(test,columns = ["country"])

# %%
test = test.set_index("person")

# %%
test

# %%
test.to_csv('data/paises_features.csv', sep=',')

# %%
df["city"].value_counts()

# %%
city = df
city = city.groupby("person")["city"].value_counts().to_frame()
city.columns = ['cant_de_apa']
city = city.reset_index()
city = city.drop("cant_de_apa",1)
city = city.drop_duplicates("person")
city
# Out:
#          person                   city
# 0      0008ed71                Unknown
# 1      00091926         Carlos Barbosa
# 2      00091a7a               Salvador
# 3      000ba417    Rio Grande da Serra
# 4      000c79fe         Belo Horizonte
# 5      000e4d9e                Igarape
# 6      000e619d              São Paulo
# 7      001001be              São Paulo
# 8      0010e89a           Miguelopolis
# 9      0016c4b5                Cajamar
# 10     001802e4                Niterói
# 11     001804a2                Unknown
# 12     0019e639              Guarulhos
# 15     001a2273                Unknown
# 16     001ca5ee             Piracicaba
# 22     001dfc31              São Paulo
# 23     001e9aea                Unknown
# 26     0020152e           Porto Alegre
# 27     00202cdb              São Paulo
# 29     0022965d            Santo André
# 32     0027574e   Sao Vicente de Minas
# 33     00295d74                Unknown
# 34     002aea56                Unknown
# ...

# %%
city_d = pd.get_dummies(city,columns = ["city"])
city_d = city_d.set_index("person")
city_d = city_d[["city_Sao Paulo","city_São Paulo"]]
city_d
# Out:
#           city_Sao Paulo  city_São Paulo
# person
# 0008ed71               0               0
# 00091926               0               0
# 00091a7a               0               0
# 000ba417               0               0
# 000c79fe               0               0
# 000e4d9e               0               0
# 000e619d               0               1
# 001001be               0               1
# 0010e89a               0               0
# 0016c4b5               0               0
# 001802e4               0               0
# 001804a2               0               0
# 0019e639               0               0
# 001a2273               0               0
# 001ca5ee               0               0
# 001dfc31               0               1
# 001e9aea               0               0
# 0020152e               0               0
# 00202cdb               0               1
# 0022965d               0               0
# 0027574e               0               0
# 00295d74               0               0
# ...

# %%
city_d.to_csv('data/city_features.csv', sep=',')

# %%
#city_d.value_counts()

# %%
dumm = df[["person","city"]]
dsa=dumm.groupby("person")["city"].value_counts().to_frame()
dsa.columns = ["cant"]
dsa = dsa.reset_index().drop_duplicates(keep="first")
dsa
