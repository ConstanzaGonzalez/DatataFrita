# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/events_up_to_01062018.csv', low_memory=False)
df.head()
# Out:
#              timestamp           event    person  url      sku  \
# 0  2018-05-18 00:11:59  viewed product  4886f805  NaN   9288.0
# 1  2018-05-18 00:11:27  viewed product  ad93850f  NaN    304.0
# 2  2018-05-18 00:11:16  viewed product  0297fc1e  NaN   6888.0
# 3  2018-05-18 00:11:14  viewed product  2d681dd8  NaN  11890.0
# 4  2018-05-18 00:11:09  viewed product  cccea85e  NaN   7517.0
#
#                      model  condition storage           color skus  \
# 0  Samsung Galaxy J7 Prime  Excelente    32GB         Dourado  NaN
# 1                iPhone 5s  Muito Bom    32GB  Cinza espacial  NaN
# 2                iPhone 6S  Muito Bom    64GB        Prateado  NaN
# 3                 iPhone 7        Bom   128GB        Vermelho  NaN
# 4              LG G4 H818P  Excelente    32GB          Branco  NaN
#
#         ...       search_engine channel new_vs_returning city region country  \
# 0       ...                 NaN     NaN              NaN  NaN    NaN     NaN
# ...

# %%
df = df.loc[df["event"] == "conversion"]
df["model_2"] = df["model"].apply(lambda x: x.split(" ")[0])
df_m = df.groupby("person")["model_2"].value_counts().to_frame()
df_m.columns = ['cant']
df_m = df_m.reset_index()
celulares = df_m["model_2"].value_counts()
celulares
# Out:
# Samsung     2191
# iPhone      1331
# Motorola     742
# LG           106
# Lenovo        73
# Sony          39
# Asus          16
# iPad           6
# Quantum        3
# Name: model_2, dtype: int64

# %%
df_m = df_m.drop_duplicates(subset="person", keep='first')
df_m
# Out:
#         person   model_2  cant
# 0     000ba417  Motorola     1
# 1     001001be    iPhone     1
# 2     001804a2    iPhone     1
# 3     0019e639  Motorola     1
# 5     001b0bf9   Samsung     1
# 6     0020152e   Samsung     1
# 7     002aea56    iPhone     4
# 8     002ed810   Samsung     2
# 9     0038a117      Asus     1
# 10    0043a48e   Samsung     3
# 11    004ed8ba   Samsung     1
# 12    00546f4c   Samsung     4
# 13    00750af8   Samsung     1
# 14    0076b7dc    iPhone     1
# 15    00971729  Motorola     1
# 16    009944e1  Motorola     1
# 17    009f8292    iPhone     2
# 18    00caa482    iPhone     4
# 19    00cd1373    iPhone     2
# 20    00ecfd1a   Samsung     1
# 21    00fa4cd7   Samsung     2
# 22    01039bf1   Samsung     1
# 23    010b0b0b   Samsung     1
# 24    011beb42    iPhone     1
# 25    0137a57b    iPhone     1
# 26    0163bf88   Samsung     1
# 27    016a78e4    iPhone     1
# 28    016b86b9   Samsung     3
# 30    016f3833   Samsung     1
# ...

# %%
df_m["compro_apple"] = df_m["model_2"].apply(lambda x: 1 if x == "iPhone" else 0)
df_m["compro_samsung"] = df_m["model_2"].apply(lambda x: 1 if x == "Samsung" else 0)
df_m["compro_motorola"] = df_m["model_2"].apply(lambda x: 1 if x == "Motorola" else 0)
#df_m["vio_mas_lg"] = df_m["model_2"].apply(lambda x: 1 if x == "LG" else 0)
df_m = df_m.set_index("person")
df_m
# Out:
#            model_2  cant  compro_apple  compro_samsung  compro_motorola
# person
# 000ba417  Motorola     1             0               0                1
# 001001be    iPhone     1             1               0                0
# 001804a2    iPhone     1             1               0                0
# 0019e639  Motorola     1             0               0                1
# 001b0bf9   Samsung     1             0               1                0
# 0020152e   Samsung     1             0               1                0
# 002aea56    iPhone     4             1               0                0
# 002ed810   Samsung     2             0               1                0
# 0038a117      Asus     1             0               0                0
# 0043a48e   Samsung     3             0               1                0
# 004ed8ba   Samsung     1             0               1                0
# 00546f4c   Samsung     4             0               1                0
# ...

# %%
df_m = df_m.drop(["model_2","cant"],1)

df_m.to_csv('data/features_compras.csv', sep=',')

# %%
df_m
# Out:
#           compro_apple  compro_samsung  compro_motorola
# person
# 000ba417             0               0                1
# 001001be             1               0                0
# 001804a2             1               0                0
# 0019e639             0               0                1
# 001b0bf9             0               1                0
# 0020152e             0               1                0
# 002aea56             1               0                0
# 002ed810             0               1                0
# 0038a117             0               0                0
# 0043a48e             0               1                0
# 004ed8ba             0               1                0
# 00546f4c             0               1                0
# 00750af8             0               1                0
# 0076b7dc             1               0                0
# 00971729             0               0                1
# 009944e1             0               0                1
# ...
